# %%
import mysql.connector as mysql
import pandas as pd

db_connection = mysql.connect(host='localhost', database='train', user='root', password='')
query = "SELECT * from train"
df_mysql = pd.read_sql(query, con = db_connection)
df_mysql
# Out:
# C:\Users\VANSH SHARMA\AppData\Local\Temp\ipykernel_18308\303903934.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql = pd.read_sql(query, con = db_connection)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# ...

# %% [markdown]
# # DISPLAY TOP 5 ROWS OF THE DATASET

# %%
df_mysql.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500            S\r
# 1      0          PC 17599  71.2833   C85      C\r
# 2      0  STON/O2. 3101282   7.9250            S\r
# 3      0            113803  53.1000  C123      S\r
# 4      0            373450   8.0500            S\r

# %% [markdown]
# # CHECK LAST 3 ROWS OF THE DATASET

# %%
df_mysql.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   0.0      1      2  W./C. 6607  23.45            S\r
# 889    male  26.0      0      0      111369  30.00  C148      C\r
# 890    male  32.0      0      0      370376   7.75            Q\r

# %% [markdown]
# # FIND SHAPE OF OUR DATASET(NUMBER OF ROWS & NUMBER OF COLUMNS)

# %%
df_mysql.shape
# Out:
# (891, 12)

# %% [markdown]
# # GET INFORMATION ABOUT OUR DATASET LIKE TOTAL NUMBER ROWS,TOTAL NUMBER OF COLUMNS,DATATYPE OF EACH COLUMN AND MEMORY REQUIREDMENT

# %%
df_mysql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # GET OVERALL STATISTICS ABOUT THE DATAFRAME

# %%
df_mysql.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   23.799293    0.523008
# std     257.353842    0.486592    0.836071   17.596074    1.102743
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    6.000000    0.000000
# 50%     446.000000    0.000000    3.000000   24.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204203
# std      0.806057   49.693412
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329000

# %% [markdown]
# # DATA FILTERING

# %%
data = df_mysql[df_mysql['PassengerId']<10]
data
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   0.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %% [markdown]
# # CHECK NULL VALUES IN THE DATASET

# %%
df_mysql.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# # DROP THE COLUMN

# %%
df_mysql.drop('Parch', axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # HANDLE MISSING VALUES

# %%
df_mysql.dropna(inplace=True)

# %% [markdown]
# # CATEGORICAL DATA ENCODING

# %%
data = pd.get_dummies(data, columns=['Pclass'], drop_first=True)
data
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
# 5            6         0                                   Moran, Mr. James
# 6            7         0                            McCarthy, Mr. Timothy J
# 7            8         0                     Palsson, Master. Gosta Leonard
# 8            9         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500            S\r
# ...

# %% [markdown]
# # WHAT IS UNIVARIATE ANALYSIS

# %%
data.columns
data['PassengerId'].describe()
# Out:
# count    9.000000
# mean     5.000000
# std      2.738613
# min      1.000000
# 25%      3.000000
# 50%      5.000000
# 75%      7.000000
# max      9.000000
# Name: PassengerId, dtype: float64

# %% [markdown]
# # HOW MANY PEOPLE SURVIVED AND HOW MANY DIED PLOT ON GRAPH

# %%
import matplotlib.pyplot as plt
import numpy as np
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='localhost', database='train', user='root', password='Vansh@123')
query = "select * from train"
df_train = pd.read_sql(query, con = db_connection)


survive = len(df_train[df_train["Survived"]==1])
nsurvive = len(df_train[df_train["Survived"]==0])
x = ['survived','not survived']
y = np.array([survive, nsurvive])

fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(y, labels=x,autopct='%1.2f%%')
plt.show()
# Out:
# C:\Users\VANSH SHARMA\AppData\Local\Temp\ipykernel_18308\2842575445.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_train = pd.read_sql(query, con = db_connection)

# %% [markdown]
# # HOW MANY PASSENGERS WERE IN FIRST CLASS,SECOND CLASS AND THIRD CLASS PLOT THOSE FIGURES ON GRAPH

# %%
import matplotlib.pyplot as plt
import numpy as np
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='localhost', database='train', user='root', password='Vansh@123')
query = "select * from train"
df_train = pd.read_sql(query, con = db_connection)


class_1 = len(df_train[df_train["Pclass"]==1])
class_2 = len(df_train[df_train["Pclass"]==2])
class_3 = len(df_train[df_train["Pclass"]==3])
x = ['first class','second class','third class']
y = np.array([class_1,class_2,class_3])

fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(y, labels=x,autopct='%1.2f%%')
plt.show()
# Out:
# C:\Users\VANSH SHARMA\AppData\Local\Temp\ipykernel_18308\1883117116.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_train = pd.read_sql(query, con = db_connection)

# %% [markdown]
# # NUMBER  OF MALE AND FEMALE PASSANGERS

# %%
print("males: ",len(df_train[df_train["Sex"]=="male"]))
print("females: ",len(df_train[df_train["Sex"]=="female"]))
# Out:
# males:  577
# females:  314

# %% [markdown]
# # BIVARIANT ANALSIS

# %%
df_train.columns
plt.figure(figsize=(8, 6))
plt.scatter(data['PassengerId'], data['Age'], color='blue', alpha=0.7)
plt.xlabel('Variable 1')
plt.ylabel('Variable 2')
plt.title('Scatter Plot of Variable 1 vs Variable 2')
plt.show()

# %% [markdown]
# # HOW HAS BETTER CANCE OF SURVIVAL MALE OR FEMALE

# %%
survival_pivot = data.pivot_table(index='Sex', columns='Survived', aggfunc='size', fill_value=0)

# Plot the survival rates
survival_pivot.plot(kind='bar', stacked=True, figsize=(8, 6), color=['red', 'green'])
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Survival Count by Sex')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # WHICH PASSENGER CLASS HAS BETTER CHANCE OF SURVIVAL(FIRST,SECOND,OR THIRD CLASS)?

# %%
import matplotlib.pyplot as plt

# Assuming 'Pclass' is the column name for passenger class in your dataset
class_survival_pivot = data.pivot_table(columns='Survived', aggfunc='size', fill_value=0)

# Plot the survival rates for passenger class
class_survival_pivot.plot(kind='bar', stacked=True, figsize=(8, 6), color=['red', 'green'])
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.title('Survival Count by Passenger Class')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # FEATURE ENGINEERING

# %%
import pandas as pd
import numpy as np

# Assuming 'data' is your original DataFrame

# Reset the index to avoid KeyError
data.reset_index(drop=True, inplace=True)

# Example: Extract titles from the 'Name' column
data['Title'] = data['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# Example: Create a new feature 'FamilySize' by combining 'SibSp' and 'Parch'
data['FamilySize'] = data['SibSp'] + data['Parch'] + 1

# Example: Create a binary 'IsAlone' feature based on 'FamilySize'
data['IsAlone'] = np.where(data['FamilySize'] == 1, 1, 0)

# Example: Convert 'Sex' to a numerical feature
data['Sex'] = data['Sex'].map({'male': 0, 'female': 1})

# Example: Binning 'Age' into age groups
bins = [0, 18, 35, 50, np.inf]
labels = ['0-18', '19-35', '36-50', '51+']
data['AgeGroup'] = pd.cut(data['Age'], bins=bins, labels=labels, right=False)

# Example: One-hot encode categorical variables (e.g., 'Embarked' and 'Pclass')
data = pd.get_dummies(data, columns=['Embarked', 'Pclass'], prefix=['Embarked', 'Pclass'])

# Display the modified DataFrame
print(data.head())
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\.'
# <>:10: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\VANSH SHARMA\AppData\Local\Temp\ipykernel_18308\389371195.py:10: SyntaxWarning: invalid escape sequence '\.'
#   data['Title'] = data['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
# C:\Users\VANSH SHARMA\AppData\Local\Temp\ipykernel_18308\389371195.py:10: SyntaxWarning: invalid escape sequence '\.'
#   data['Title'] = data['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 27
#      24 data['AgeGroup'] = pd.cut(data['Age'], bins=bins, labels=labels, right=False)
#      26 # Example: One-hot encode categorical variables (e.g., 'Embarked' and 'Pclass')
# ---> 27 data = pd.get_dummies(data, columns=['Embarked', 'Pclass'], prefix=['Embarked', 'Pclass'])
# ...
